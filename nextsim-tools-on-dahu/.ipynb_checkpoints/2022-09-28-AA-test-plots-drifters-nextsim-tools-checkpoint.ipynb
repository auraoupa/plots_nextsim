# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.tri import Triangulation
from matplotlib import cm, patches, collections

from pynextsim import NextsimBin
from pynextsim.nextsim_mesh import NextsimMesh

from pynextsim.gmshlib import GmshMesh

from pynextsim.drifter_time_series import *

# %matplotlib notebook

# %%
mesh_file='/data/experiments/run_330d_nodebug/mesh_final.bin'
mesh = NextsimMesh(mesh_file)

# %%
field_file='/data/experiments/run_330d_nodebug/field_final.bin'
field = NextsimBin(field_file)

# %%
drifters_file='/data/experiments/run_330d_nodebug/test_drifters.nc'

# %%
drft_datetimes, drft_indices, drft_data = read_nextsim_drifter_netcdf_file(drifters_file)

# %%
drft_c = DrifterTimeSeries(datetimes=drft_datetimes, indices=drft_indices, data=drft_data)

# %%
[xmin,xmax,ymin,ymax]=drft_c.get_xy_extent()

# %%
print(xmin,xmax,ymin,ymax)
# Out:
# -1707981.123168879 1009473.1907321878 -1122643.8316641136 932904.7611514851

# %%
drft_c.overlay_trajectories_on_model_field(field_file)
# Out:
# Plot field M_VT (quiver)
# <img src="data:image/png;base64,..." width="640">
# Plot 81 trajectories
# <img src="data:image/png;base64,..." width="640">

# %%
import swarp_funs.mod_netcdf_utils as mnu

# %%
# ?mnu

# %%
from netCDF4 import Dataset as ncopen

nc=ncopen(drifters_file)

# %%
print(nc.dimensions)
# Out:
# {'time': <class 'netCDF4._netCDF4.Dimension'> (unlimited): name = 'time', size = 1321, 'nv': <class 'netCDF4._netCDF4.Dimension'>: name = 'nv', size = 2, 'x': <class 'netCDF4._netCDF4.Dimension'>: name = 'x', size = 391, 'y': <class 'netCDF4._netCDF4.Dimension'>: name = 'y', size = 326}

# %%
time = nc.variables['time']

# %%
fmt  = '%Y-%m-%d %H:%M:%S'
tu        = time.units
print(tu)
# Out:
# days since 1900-01-01 00:00:00

# %%
from netcdftime import utime
# ?utime

# %%
time_converter = utime(tu,calendar=time.calendar)

# %%
time_converter.units.lower()
# Out:
# 'days'

# %%
arr             = time[:]
datetimes  = []
timevalues = []
Unit = time_converter.units.lower()

# %%
from datetime import datetime,timedelta

# %%
        for i, tval in enumerate(arr):
            if isinstance(tval, np.int32):
                # can be problems if int32 format
                tval  = int(tval)
            try:
                cdate = time_converter.num2date(tval).strftime(fmt)
            except ValueError:
                # might get errors if close to end/start of month
                # eg CS2-SMOS
                tval=round(float(tval))
                cdate = time_converter.num2date(tval).strftime(fmt)
            dto    = datetime.strptime(cdate, fmt)         # now a proper datetime object
            datetimes.append(dto)

            if i==0:
                reftime  = dto

            tdiff = (dto-reftime).total_seconds()
            if Unit=='seconds':
                timevalues.append(tdiff/3600.)         # convert to hours for readability
                timeunits = 'hour'
            elif Unit=='hours':
                timevalues.append(tdiff/3600.)         # keep as hours
                timeunits = 'hour'
            elif Unit=='days':
                timevalues.append(tdiff/3600./24.)    # keep as days
                timeunits = 'day'

        number_of_time_records    = len(datetimes)

# %%
number_of_time_records
# Out:
# 1321

# %%
datetimes
# Out:
# [datetime.datetime(2006, 2, 1, 0, 0),
#  datetime.datetime(2006, 2, 1, 6, 0),
#  datetime.datetime(2006, 2, 1, 12, 0),
#  datetime.datetime(2006, 2, 1, 18, 0),
#  datetime.datetime(2006, 2, 2, 0, 0),
#  datetime.datetime(2006, 2, 2, 6, 0),
#  datetime.datetime(2006, 2, 2, 12, 0),
#  datetime.datetime(2006, 2, 2, 18, 0),
#  datetime.datetime(2006, 2, 3, 0, 0),
#  datetime.datetime(2006, 2, 3, 6, 0),
#  datetime.datetime(2006, 2, 3, 12, 0),
#  datetime.datetime(2006, 2, 3, 18, 0),
#  datetime.datetime(2006, 2, 4, 0, 0),
#  datetime.datetime(2006, 2, 4, 6, 0),
#  datetime.datetime(2006, 2, 4, 12, 0),
#  datetime.datetime(2006, 2, 4, 18, 0),
#  datetime.datetime(2006, 2, 5, 0, 0),
#  datetime.datetime(2006, 2, 5, 6, 0),
#  datetime.datetime(2006, 2, 5, 12, 0),
#  datetime.datetime(2006, 2, 5, 18, 0),
#  datetime.datetime(2006, 2, 6, 0, 0),
#  datetime.datetime(2006, 2, 6, 6, 0),
#  datetime.datetime(2006, 2, 6, 12, 0),
#  datetime.datetime(2006, 2, 6, 18, 0),
#  datetime.datetime(2006, 2, 7, 0, 0),
#  datetime.datetime(2006, 2, 7, 6, 0),
#  datetime.datetime(2006, 2, 7, 12, 0),
#  datetime.datetime(2006, 2, 7, 18, 0),
#  datetime.datetime(2006, 2, 8, 0, 0),
#  datetime.datetime(2006, 2, 8, 6, 0),
#  datetime.datetime(2006, 2, 8, 12, 0),
#  datetime.datetime(2006, 2, 8, 18, 0),
#  datetime.datetime(2006, 2, 9, 0, 0),
#  datetime.datetime(2006, 2, 9, 6, 0),
#  datetime.datetime(2006, 2, 9, 12, 0),
#  datetime.datetime(2006, 2, 9, 18, 0),
#  datetime.datetime(2006, 2, 10, 0, 0),
#  datetime.datetime(2006, 2, 10, 6, 0),
#  datetime.datetime(2006, 2, 10, 12, 0),
#  datetime.datetime(2006, 2, 10, 18, 0),
#  datetime.datetime(2006, 2, 11, 0, 0),
#  datetime.datetime(2006, 2, 11, 6, 0),
#  datetime.datetime(2006, 2, 11, 12, 0),
#  datetime.datetime(2006, 2, 11, 18, 0),
#  datetime.datetime(2006, 2, 12, 0, 0),
#  datetime.datetime(2006, 2, 12, 6, 0),
#  datetime.datetime(2006, 2, 12, 12, 0),
#  datetime.datetime(2006, 2, 12, 18, 0),
#  datetime.datetime(2006, 2, 13, 0, 0),
#  datetime.datetime(2006, 2, 13, 6, 0),
#  datetime.datetime(2006, 2, 13, 12, 0),
#  datetime.datetime(2006, 2, 13, 18, 0),
#  datetime.datetime(2006, 2, 14, 0, 0),
#  datetime.datetime(2006, 2, 14, 6, 0),
#  datetime.datetime(2006, 2, 14, 12, 0),
#  datetime.datetime(2006, 2, 14, 18, 0),
#  datetime.datetime(2006, 2, 15, 0, 0),
#  datetime.datetime(2006, 2, 15, 6, 0),
#  datetime.datetime(2006, 2, 15, 12, 0),
#  datetime.datetime(2006, 2, 15, 18, 0),
#  datetime.datetime(2006, 2, 16, 0, 0),
#  datetime.datetime(2006, 2, 16, 6, 0),
#  datetime.datetime(2006, 2, 16, 12, 0),
#  datetime.datetime(2006, 2, 16, 18, 0),
#  datetime.datetime(2006, 2, 17, 0, 0),
#  datetime.datetime(2006, 2, 17, 6, 0),
#  datetime.datetime(2006, 2, 17, 12, 0),
#  datetime.datetime(2006, 2, 17, 18, 0),
#  datetime.datetime(2006, 2, 18, 0, 0),
#  datetime.datetime(2006, 2, 18, 6, 0),
#  datetime.datetime(2006, 2, 18, 12, 0),
#  datetime.datetime(2006, 2, 18, 18, 0),
#  datetime.datetime(2006, 2, 19, 0, 0),
#  datetime.datetime(2006, 2, 19, 6, 0),
#  datetime.datetime(2006, 2, 19, 12, 0),
#  datetime.datetime(2006, 2, 19, 18, 0),
#  datetime.datetime(2006, 2, 20, 0, 0),
#  datetime.datetime(2006, 2, 20, 6, 0),
#  datetime.datetime(2006, 2, 20, 12, 0),
#  datetime.datetime(2006, 2, 20, 18, 0),
#  datetime.datetime(2006, 2, 21, 0, 0),
#  datetime.datetime(2006, 2, 21, 6, 0),
#  datetime.datetime(2006, 2, 21, 12, 0),
#  datetime.datetime(2006, 2, 21, 18, 0),
#  datetime.datetime(2006, 2, 22, 0, 0),
#  datetime.datetime(2006, 2, 22, 6, 0),
#  datetime.datetime(2006, 2, 22, 12, 0),
#  datetime.datetime(2006, 2, 22, 18, 0),
#  datetime.datetime(2006, 2, 23, 0, 0),
#  datetime.datetime(2006, 2, 23, 6, 0),
#  datetime.datetime(2006, 2, 23, 12, 0),
#  datetime.datetime(2006, 2, 23, 18, 0),
#  datetime.datetime(2006, 2, 24, 0, 0),
#  datetime.datetime(2006, 2, 24, 6, 0),
#  datetime.datetime(2006, 2, 24, 12, 0),
#  datetime.datetime(2006, 2, 24, 18, 0),
#  datetime.datetime(2006, 2, 25, 0, 0),
#  datetime.datetime(2006, 2, 25, 6, 0),
#  datetime.datetime(2006, 2, 25, 12, 0),
#  datetime.datetime(2006, 2, 25, 18, 0),
#  datetime.datetime(2006, 2, 26, 0, 0),
#  datetime.datetime(2006, 2, 26, 6, 0),
#  datetime.datetime(2006, 2, 26, 12, 0),
#  datetime.datetime(2006, 2, 26, 18, 0),
#  datetime.datetime(2006, 2, 27, 0, 0),
#  datetime.datetime(2006, 2, 27, 6, 0),
#  datetime.datetime(2006, 2, 27, 12, 0),
#  datetime.datetime(2006, 2, 27, 18, 0),
#  datetime.datetime(2006, 2, 28, 0, 0),
#  datetime.datetime(2006, 2, 28, 6, 0),
#  datetime.datetime(2006, 2, 28, 12, 0),
#  datetime.datetime(2006, 2, 28, 18, 0),
#  datetime.datetime(2006, 3, 1, 0, 0),
#  datetime.datetime(2006, 3, 1, 6, 0),
#  datetime.datetime(2006, 3, 1, 12, 0),
#  datetime.datetime(2006, 3, 1, 18, 0),
#  datetime.datetime(2006, 3, 2, 0, 0),
#  datetime.datetime(2006, 3, 2, 6, 0),
#  datetime.datetime(2006, 3, 2, 12, 0),
#  datetime.datetime(2006, 3, 2, 18, 0),
#  datetime.datetime(2006, 3, 3, 0, 0),
#  datetime.datetime(2006, 3, 3, 6, 0),
#  datetime.datetime(2006, 3, 3, 12, 0),
#  datetime.datetime(2006, 3, 3, 18, 0),
#  datetime.datetime(2006, 3, 4, 0, 0),
#  datetime.datetime(2006, 3, 4, 6, 0),
#  datetime.datetime(2006, 3, 4, 12, 0),
#  datetime.datetime(2006, 3, 4, 18, 0),
#  datetime.datetime(2006, 3, 5, 0, 0),
#  datetime.datetime(2006, 3, 5, 6, 0),
#  datetime.datetime(2006, 3, 5, 12, 0),
#  datetime.datetime(2006, 3, 5, 18, 0),
#  datetime.datetime(2006, 3, 6, 0, 0),
#  datetime.datetime(2006, 3, 6, 6, 0),
#  datetime.datetime(2006, 3, 6, 12, 0),
#  datetime.datetime(2006, 3, 6, 18, 0),
#  datetime.datetime(2006, 3, 7, 0, 0),
#  datetime.datetime(2006, 3, 7, 6, 0),
#  datetime.datetime(2006, 3, 7, 12, 0),
#  datetime.datetime(2006, 3, 7, 18, 0),
#  datetime.datetime(2006, 3, 8, 0, 0),
#  datetime.datetime(2006, 3, 8, 6, 0),
#  datetime.datetime(2006, 3, 8, 12, 0),
#  datetime.datetime(2006, 3, 8, 18, 0),
#  datetime.datetime(2006, 3, 9, 0, 0),
#  datetime.datetime(2006, 3, 9, 6, 0),
#  datetime.datetime(2006, 3, 9, 12, 0),
#  datetime.datetime(2006, 3, 9, 18, 0),
#  datetime.datetime(2006, 3, 10, 0, 0),
#  datetime.datetime(2006, 3, 10, 6, 0),
#  datetime.datetime(2006, 3, 10, 12, 0),
#  datetime.datetime(2006, 3, 10, 18, 0),
#  datetime.datetime(2006, 3, 11, 0, 0),
#  datetime.datetime(2006, 3, 11, 6, 0),
#  datetime.datetime(2006, 3, 11, 12, 0),
#  datetime.datetime(2006, 3, 11, 18, 0),
#  datetime.datetime(2006, 3, 12, 0, 0),
#  datetime.datetime(2006, 3, 12, 6, 0),
#  datetime.datetime(2006, 3, 12, 12, 0),
#  datetime.datetime(2006, 3, 12, 18, 0),
#  datetime.datetime(2006, 3, 13, 0, 0),
#  datetime.datetime(2006, 3, 13, 6, 0),
#  datetime.datetime(2006, 3, 13, 12, 0),
#  datetime.datetime(2006, 3, 13, 18, 0),
#  datetime.datetime(2006, 3, 14, 0, 0),
#  datetime.datetime(2006, 3, 14, 6, 0),
#  datetime.datetime(2006, 3, 14, 12, 0),
#  datetime.datetime(2006, 3, 14, 18, 0),
#  datetime.datetime(2006, 3, 15, 0, 0),
#  datetime.datetime(2006, 3, 15, 6, 0),
#  datetime.datetime(2006, 3, 15, 12, 0),
#  datetime.datetime(2006, 3, 15, 18, 0),
#  datetime.datetime(2006, 3, 16, 0, 0),
#  datetime.datetime(2006, 3, 16, 6, 0),
#  datetime.datetime(2006, 3, 16, 12, 0),
#  datetime.datetime(2006, 3, 16, 18, 0),
#  datetime.datetime(2006, 3, 17, 0, 0),
#  datetime.datetime(2006, 3, 17, 6, 0),
#  datetime.datetime(2006, 3, 17, 12, 0),
#  datetime.datetime(2006, 3, 17, 18, 0),
#  datetime.datetime(2006, 3, 18, 0, 0),
#  datetime.datetime(2006, 3, 18, 6, 0),
#  datetime.datetime(2006, 3, 18, 12, 0),
#  datetime.datetime(2006, 3, 18, 18, 0),
#  datetime.datetime(2006, 3, 19, 0, 0),
#  datetime.datetime(2006, 3, 19, 6, 0),
#  datetime.datetime(2006, 3, 19, 12, 0),
#  datetime.datetime(2006, 3, 19, 18, 0),
#  datetime.datetime(2006, 3, 20, 0, 0),
#  datetime.datetime(2006, 3, 20, 6, 0),
#  datetime.datetime(2006, 3, 20, 12, 0),
#  datetime.datetime(2006, 3, 20, 18, 0),
#  datetime.datetime(2006, 3, 21, 0, 0),
#  datetime.datetime(2006, 3, 21, 6, 0),
#  datetime.datetime(2006, 3, 21, 12, 0),
#  datetime.datetime(2006, 3, 21, 18, 0),
#  datetime.datetime(2006, 3, 22, 0, 0),
#  datetime.datetime(2006, 3, 22, 6, 0),
#  datetime.datetime(2006, 3, 22, 12, 0),
#  datetime.datetime(2006, 3, 22, 18, 0),
#  datetime.datetime(2006, 3, 23, 0, 0),
#  datetime.datetime(2006, 3, 23, 6, 0),
#  datetime.datetime(2006, 3, 23, 12, 0),
#  datetime.datetime(2006, 3, 23, 18, 0),
#  datetime.datetime(2006, 3, 24, 0, 0),
#  datetime.datetime(2006, 3, 24, 6, 0),
#  datetime.datetime(2006, 3, 24, 12, 0),
#  datetime.datetime(2006, 3, 24, 18, 0),
#  datetime.datetime(2006, 3, 25, 0, 0),
#  datetime.datetime(2006, 3, 25, 6, 0),
#  datetime.datetime(2006, 3, 25, 12, 0),
#  datetime.datetime(2006, 3, 25, 18, 0),
#  datetime.datetime(2006, 3, 26, 0, 0),
#  datetime.datetime(2006, 3, 26, 6, 0),
#  datetime.datetime(2006, 3, 26, 12, 0),
#  datetime.datetime(2006, 3, 26, 18, 0),
#  datetime.datetime(2006, 3, 27, 0, 0),
#  datetime.datetime(2006, 3, 27, 6, 0),
#  datetime.datetime(2006, 3, 27, 12, 0),
#  datetime.datetime(2006, 3, 27, 18, 0),
#  datetime.datetime(2006, 3, 28, 0, 0),
#  datetime.datetime(2006, 3, 28, 6, 0),
#  datetime.datetime(2006, 3, 28, 12, 0),
#  datetime.datetime(2006, 3, 28, 18, 0),
#  datetime.datetime(2006, 3, 29, 0, 0),
#  datetime.datetime(2006, 3, 29, 6, 0),
#  datetime.datetime(2006, 3, 29, 12, 0),
#  datetime.datetime(2006, 3, 29, 18, 0),
#  datetime.datetime(2006, 3, 30, 0, 0),
#  datetime.datetime(2006, 3, 30, 6, 0),
#  datetime.datetime(2006, 3, 30, 12, 0),
#  datetime.datetime(2006, 3, 30, 18, 0),
#  datetime.datetime(2006, 3, 31, 0, 0),
#  datetime.datetime(2006, 3, 31, 6, 0),
#  datetime.datetime(2006, 3, 31, 12, 0),
#  datetime.datetime(2006, 3, 31, 18, 0),
#  datetime.datetime(2006, 4, 1, 0, 0),
#  datetime.datetime(2006, 4, 1, 6, 0),
#  datetime.datetime(2006, 4, 1, 12, 0),
#  datetime.datetime(2006, 4, 1, 18, 0),
#  datetime.datetime(2006, 4, 2, 0, 0),
#  datetime.datetime(2006, 4, 2, 6, 0),
#  datetime.datetime(2006, 4, 2, 12, 0),
#  datetime.datetime(2006, 4, 2, 18, 0),
#  datetime.datetime(2006, 4, 3, 0, 0),
#  datetime.datetime(2006, 4, 3, 6, 0),
#  datetime.datetime(2006, 4, 3, 12, 0),
#  datetime.datetime(2006, 4, 3, 18, 0),
#  datetime.datetime(2006, 4, 4, 0, 0),
#  datetime.datetime(2006, 4, 4, 6, 0),
#  datetime.datetime(2006, 4, 4, 12, 0),
#  datetime.datetime(2006, 4, 4, 18, 0),
#  datetime.datetime(2006, 4, 5, 0, 0),
#  datetime.datetime(2006, 4, 5, 6, 0),
#  datetime.datetime(2006, 4, 5, 12, 0),
#  datetime.datetime(2006, 4, 5, 18, 0),
#  datetime.datetime(2006, 4, 6, 0, 0),
#  datetime.datetime(2006, 4, 6, 6, 0),
#  datetime.datetime(2006, 4, 6, 12, 0),
#  datetime.datetime(2006, 4, 6, 18, 0),
#  datetime.datetime(2006, 4, 7, 0, 0),
#  datetime.datetime(2006, 4, 7, 6, 0),
#  datetime.datetime(2006, 4, 7, 12, 0),
#  datetime.datetime(2006, 4, 7, 18, 0),
#  datetime.datetime(2006, 4, 8, 0, 0),
#  datetime.datetime(2006, 4, 8, 6, 0),
#  datetime.datetime(2006, 4, 8, 12, 0),
#  datetime.datetime(2006, 4, 8, 18, 0),
#  datetime.datetime(2006, 4, 9, 0, 0),
#  datetime.datetime(2006, 4, 9, 6, 0),
#  datetime.datetime(2006, 4, 9, 12, 0),
#  datetime.datetime(2006, 4, 9, 18, 0),
#  datetime.datetime(2006, 4, 10, 0, 0),
#  datetime.datetime(2006, 4, 10, 6, 0),
#  datetime.datetime(2006, 4, 10, 12, 0),
#  datetime.datetime(2006, 4, 10, 18, 0),
#  datetime.datetime(2006, 4, 11, 0, 0),
#  datetime.datetime(2006, 4, 11, 6, 0),
#  datetime.datetime(2006, 4, 11, 12, 0),
#  datetime.datetime(2006, 4, 11, 18, 0),
#  datetime.datetime(2006, 4, 12, 0, 0),
#  datetime.datetime(2006, 4, 12, 6, 0),
#  datetime.datetime(2006, 4, 12, 12, 0),
#  datetime.datetime(2006, 4, 12, 18, 0),
#  datetime.datetime(2006, 4, 13, 0, 0),
#  datetime.datetime(2006, 4, 13, 6, 0),
#  datetime.datetime(2006, 4, 13, 12, 0),
#  datetime.datetime(2006, 4, 13, 18, 0),
#  datetime.datetime(2006, 4, 14, 0, 0),
#  datetime.datetime(2006, 4, 14, 6, 0),
#  datetime.datetime(2006, 4, 14, 12, 0),
#  datetime.datetime(2006, 4, 14, 18, 0),
#  datetime.datetime(2006, 4, 15, 0, 0),
#  datetime.datetime(2006, 4, 15, 6, 0),
#  datetime.datetime(2006, 4, 15, 12, 0),
#  datetime.datetime(2006, 4, 15, 18, 0),
#  datetime.datetime(2006, 4, 16, 0, 0),
#  datetime.datetime(2006, 4, 16, 6, 0),
#  datetime.datetime(2006, 4, 16, 12, 0),
#  datetime.datetime(2006, 4, 16, 18, 0),
#  datetime.datetime(2006, 4, 17, 0, 0),
#  datetime.datetime(2006, 4, 17, 6, 0),
#  datetime.datetime(2006, 4, 17, 12, 0),
#  datetime.datetime(2006, 4, 17, 18, 0),
#  datetime.datetime(2006, 4, 18, 0, 0),
#  datetime.datetime(2006, 4, 18, 6, 0),
#  datetime.datetime(2006, 4, 18, 12, 0),
#  datetime.datetime(2006, 4, 18, 18, 0),
#  datetime.datetime(2006, 4, 19, 0, 0),
#  datetime.datetime(2006, 4, 19, 6, 0),
#  datetime.datetime(2006, 4, 19, 12, 0),
#  datetime.datetime(2006, 4, 19, 18, 0),
#  datetime.datetime(2006, 4, 20, 0, 0),
#  datetime.datetime(2006, 4, 20, 6, 0),
#  datetime.datetime(2006, 4, 20, 12, 0),
#  datetime.datetime(2006, 4, 20, 18, 0),
#  datetime.datetime(2006, 4, 21, 0, 0),
#  datetime.datetime(2006, 4, 21, 6, 0),
#  datetime.datetime(2006, 4, 21, 12, 0),
#  datetime.datetime(2006, 4, 21, 18, 0),
#  datetime.datetime(2006, 4, 22, 0, 0),
#  datetime.datetime(2006, 4, 22, 6, 0),
#  datetime.datetime(2006, 4, 22, 12, 0),
#  datetime.datetime(2006, 4, 22, 18, 0),
#  datetime.datetime(2006, 4, 23, 0, 0),
#  datetime.datetime(2006, 4, 23, 6, 0),
#  datetime.datetime(2006, 4, 23, 12, 0),
#  datetime.datetime(2006, 4, 23, 18, 0),
#  datetime.datetime(2006, 4, 24, 0, 0),
#  datetime.datetime(2006, 4, 24, 6, 0),
#  datetime.datetime(2006, 4, 24, 12, 0),
#  datetime.datetime(2006, 4, 24, 18, 0),
#  datetime.datetime(2006, 4, 25, 0, 0),
#  datetime.datetime(2006, 4, 25, 6, 0),
#  datetime.datetime(2006, 4, 25, 12, 0),
#  datetime.datetime(2006, 4, 25, 18, 0),
#  datetime.datetime(2006, 4, 26, 0, 0),
#  datetime.datetime(2006, 4, 26, 6, 0),
#  datetime.datetime(2006, 4, 26, 12, 0),
#  datetime.datetime(2006, 4, 26, 18, 0),
#  datetime.datetime(2006, 4, 27, 0, 0),
#  datetime.datetime(2006, 4, 27, 6, 0),
#  datetime.datetime(2006, 4, 27, 12, 0),
#  datetime.datetime(2006, 4, 27, 18, 0),
#  datetime.datetime(2006, 4, 28, 0, 0),
#  datetime.datetime(2006, 4, 28, 6, 0),
#  datetime.datetime(2006, 4, 28, 12, 0),
#  datetime.datetime(2006, 4, 28, 18, 0),
#  datetime.datetime(2006, 4, 29, 0, 0),
#  datetime.datetime(2006, 4, 29, 6, 0),
#  datetime.datetime(2006, 4, 29, 12, 0),
#  datetime.datetime(2006, 4, 29, 18, 0),
#  datetime.datetime(2006, 4, 30, 0, 0),
#  datetime.datetime(2006, 4, 30, 6, 0),
#  datetime.datetime(2006, 4, 30, 12, 0),
#  datetime.datetime(2006, 4, 30, 18, 0),
#  datetime.datetime(2006, 5, 1, 0, 0),
#  datetime.datetime(2006, 5, 1, 6, 0),
#  datetime.datetime(2006, 5, 1, 12, 0),
#  datetime.datetime(2006, 5, 1, 18, 0),
#  datetime.datetime(2006, 5, 2, 0, 0),
#  datetime.datetime(2006, 5, 2, 6, 0),
#  datetime.datetime(2006, 5, 2, 12, 0),
#  datetime.datetime(2006, 5, 2, 18, 0),
#  datetime.datetime(2006, 5, 3, 0, 0),
#  datetime.datetime(2006, 5, 3, 6, 0),
#  datetime.datetime(2006, 5, 3, 12, 0),
#  datetime.datetime(2006, 5, 3, 18, 0),
#  datetime.datetime(2006, 5, 4, 0, 0),
#  datetime.datetime(2006, 5, 4, 6, 0),
#  datetime.datetime(2006, 5, 4, 12, 0),
#  datetime.datetime(2006, 5, 4, 18, 0),
#  datetime.datetime(2006, 5, 5, 0, 0),
#  datetime.datetime(2006, 5, 5, 6, 0),
#  datetime.datetime(2006, 5, 5, 12, 0),
#  datetime.datetime(2006, 5, 5, 18, 0),
#  datetime.datetime(2006, 5, 6, 0, 0),
#  datetime.datetime(2006, 5, 6, 6, 0),
#  datetime.datetime(2006, 5, 6, 12, 0),
#  datetime.datetime(2006, 5, 6, 18, 0),
#  datetime.datetime(2006, 5, 7, 0, 0),
#  datetime.datetime(2006, 5, 7, 6, 0),
#  datetime.datetime(2006, 5, 7, 12, 0),
#  datetime.datetime(2006, 5, 7, 18, 0),
#  datetime.datetime(2006, 5, 8, 0, 0),
#  datetime.datetime(2006, 5, 8, 6, 0),
#  datetime.datetime(2006, 5, 8, 12, 0),
#  datetime.datetime(2006, 5, 8, 18, 0),
#  datetime.datetime(2006, 5, 9, 0, 0),
#  datetime.datetime(2006, 5, 9, 6, 0),
#  datetime.datetime(2006, 5, 9, 12, 0),
#  datetime.datetime(2006, 5, 9, 18, 0),
#  datetime.datetime(2006, 5, 10, 0, 0),
#  datetime.datetime(2006, 5, 10, 6, 0),
#  datetime.datetime(2006, 5, 10, 12, 0),
#  datetime.datetime(2006, 5, 10, 18, 0),
#  datetime.datetime(2006, 5, 11, 0, 0),
#  datetime.datetime(2006, 5, 11, 6, 0),
#  datetime.datetime(2006, 5, 11, 12, 0),
#  datetime.datetime(2006, 5, 11, 18, 0),
#  datetime.datetime(2006, 5, 12, 0, 0),
#  datetime.datetime(2006, 5, 12, 6, 0),
#  datetime.datetime(2006, 5, 12, 12, 0),
#  datetime.datetime(2006, 5, 12, 18, 0),
#  datetime.datetime(2006, 5, 13, 0, 0),
#  datetime.datetime(2006, 5, 13, 6, 0),
#  datetime.datetime(2006, 5, 13, 12, 0),
#  datetime.datetime(2006, 5, 13, 18, 0),
#  datetime.datetime(2006, 5, 14, 0, 0),
#  datetime.datetime(2006, 5, 14, 6, 0),
#  datetime.datetime(2006, 5, 14, 12, 0),
#  datetime.datetime(2006, 5, 14, 18, 0),
#  datetime.datetime(2006, 5, 15, 0, 0),
#  datetime.datetime(2006, 5, 15, 6, 0),
#  datetime.datetime(2006, 5, 15, 12, 0),
#  datetime.datetime(2006, 5, 15, 18, 0),
#  datetime.datetime(2006, 5, 16, 0, 0),
#  datetime.datetime(2006, 5, 16, 6, 0),
#  datetime.datetime(2006, 5, 16, 12, 0),
#  datetime.datetime(2006, 5, 16, 18, 0),
#  datetime.datetime(2006, 5, 17, 0, 0),
#  datetime.datetime(2006, 5, 17, 6, 0),
#  datetime.datetime(2006, 5, 17, 12, 0),
#  datetime.datetime(2006, 5, 17, 18, 0),
#  datetime.datetime(2006, 5, 18, 0, 0),
#  datetime.datetime(2006, 5, 18, 6, 0),
#  datetime.datetime(2006, 5, 18, 12, 0),
#  datetime.datetime(2006, 5, 18, 18, 0),
#  datetime.datetime(2006, 5, 19, 0, 0),
#  datetime.datetime(2006, 5, 19, 6, 0),
#  datetime.datetime(2006, 5, 19, 12, 0),
#  datetime.datetime(2006, 5, 19, 18, 0),
#  datetime.datetime(2006, 5, 20, 0, 0),
#  datetime.datetime(2006, 5, 20, 6, 0),
#  datetime.datetime(2006, 5, 20, 12, 0),
#  datetime.datetime(2006, 5, 20, 18, 0),
#  datetime.datetime(2006, 5, 21, 0, 0),
#  datetime.datetime(2006, 5, 21, 6, 0),
#  datetime.datetime(2006, 5, 21, 12, 0),
#  datetime.datetime(2006, 5, 21, 18, 0),
#  datetime.datetime(2006, 5, 22, 0, 0),
#  datetime.datetime(2006, 5, 22, 6, 0),
#  datetime.datetime(2006, 5, 22, 12, 0),
#  datetime.datetime(2006, 5, 22, 18, 0),
#  datetime.datetime(2006, 5, 23, 0, 0),
#  datetime.datetime(2006, 5, 23, 6, 0),
#  datetime.datetime(2006, 5, 23, 12, 0),
#  datetime.datetime(2006, 5, 23, 18, 0),
#  datetime.datetime(2006, 5, 24, 0, 0),
#  datetime.datetime(2006, 5, 24, 6, 0),
#  datetime.datetime(2006, 5, 24, 12, 0),
#  datetime.datetime(2006, 5, 24, 18, 0),
#  datetime.datetime(2006, 5, 25, 0, 0),
#  datetime.datetime(2006, 5, 25, 6, 0),
#  datetime.datetime(2006, 5, 25, 12, 0),
#  datetime.datetime(2006, 5, 25, 18, 0),
#  datetime.datetime(2006, 5, 26, 0, 0),
#  datetime.datetime(2006, 5, 26, 6, 0),
#  datetime.datetime(2006, 5, 26, 12, 0),
#  datetime.datetime(2006, 5, 26, 18, 0),
#  datetime.datetime(2006, 5, 27, 0, 0),
#  datetime.datetime(2006, 5, 27, 6, 0),
#  datetime.datetime(2006, 5, 27, 12, 0),
#  datetime.datetime(2006, 5, 27, 18, 0),
#  datetime.datetime(2006, 5, 28, 0, 0),
#  datetime.datetime(2006, 5, 28, 6, 0),
#  datetime.datetime(2006, 5, 28, 12, 0),
#  datetime.datetime(2006, 5, 28, 18, 0),
#  datetime.datetime(2006, 5, 29, 0, 0),
#  datetime.datetime(2006, 5, 29, 6, 0),
#  datetime.datetime(2006, 5, 29, 12, 0),
#  datetime.datetime(2006, 5, 29, 18, 0),
#  datetime.datetime(2006, 5, 30, 0, 0),
#  datetime.datetime(2006, 5, 30, 6, 0),
#  datetime.datetime(2006, 5, 30, 12, 0),
#  datetime.datetime(2006, 5, 30, 18, 0),
#  datetime.datetime(2006, 5, 31, 0, 0),
#  datetime.datetime(2006, 5, 31, 6, 0),
#  datetime.datetime(2006, 5, 31, 12, 0),
#  datetime.datetime(2006, 5, 31, 18, 0),
#  datetime.datetime(2006, 6, 1, 0, 0),
#  datetime.datetime(2006, 6, 1, 6, 0),
#  datetime.datetime(2006, 6, 1, 12, 0),
#  datetime.datetime(2006, 6, 1, 18, 0),
#  datetime.datetime(2006, 6, 2, 0, 0),
#  datetime.datetime(2006, 6, 2, 6, 0),
#  datetime.datetime(2006, 6, 2, 12, 0),
#  datetime.datetime(2006, 6, 2, 18, 0),
#  datetime.datetime(2006, 6, 3, 0, 0),
#  datetime.datetime(2006, 6, 3, 6, 0),
#  datetime.datetime(2006, 6, 3, 12, 0),
#  datetime.datetime(2006, 6, 3, 18, 0),
#  datetime.datetime(2006, 6, 4, 0, 0),
#  datetime.datetime(2006, 6, 4, 6, 0),
#  datetime.datetime(2006, 6, 4, 12, 0),
#  datetime.datetime(2006, 6, 4, 18, 0),
#  datetime.datetime(2006, 6, 5, 0, 0),
#  datetime.datetime(2006, 6, 5, 6, 0),
#  datetime.datetime(2006, 6, 5, 12, 0),
#  datetime.datetime(2006, 6, 5, 18, 0),
#  datetime.datetime(2006, 6, 6, 0, 0),
#  datetime.datetime(2006, 6, 6, 6, 0),
#  datetime.datetime(2006, 6, 6, 12, 0),
#  datetime.datetime(2006, 6, 6, 18, 0),
#  datetime.datetime(2006, 6, 7, 0, 0),
#  datetime.datetime(2006, 6, 7, 6, 0),
#  datetime.datetime(2006, 6, 7, 12, 0),
#  datetime.datetime(2006, 6, 7, 18, 0),
#  datetime.datetime(2006, 6, 8, 0, 0),
#  datetime.datetime(2006, 6, 8, 6, 0),
#  datetime.datetime(2006, 6, 8, 12, 0),
#  datetime.datetime(2006, 6, 8, 18, 0),
#  datetime.datetime(2006, 6, 9, 0, 0),
#  datetime.datetime(2006, 6, 9, 6, 0),
#  datetime.datetime(2006, 6, 9, 12, 0),
#  datetime.datetime(2006, 6, 9, 18, 0),
#  datetime.datetime(2006, 6, 10, 0, 0),
#  datetime.datetime(2006, 6, 10, 6, 0),
#  datetime.datetime(2006, 6, 10, 12, 0),
#  datetime.datetime(2006, 6, 10, 18, 0),
#  datetime.datetime(2006, 6, 11, 0, 0),
#  datetime.datetime(2006, 6, 11, 6, 0),
#  datetime.datetime(2006, 6, 11, 12, 0),
#  datetime.datetime(2006, 6, 11, 18, 0),
#  datetime.datetime(2006, 6, 12, 0, 0),
#  datetime.datetime(2006, 6, 12, 6, 0),
#  datetime.datetime(2006, 6, 12, 12, 0),
#  datetime.datetime(2006, 6, 12, 18, 0),
#  datetime.datetime(2006, 6, 13, 0, 0),
#  datetime.datetime(2006, 6, 13, 6, 0),
#  datetime.datetime(2006, 6, 13, 12, 0),
#  datetime.datetime(2006, 6, 13, 18, 0),
#  datetime.datetime(2006, 6, 14, 0, 0),
#  datetime.datetime(2006, 6, 14, 6, 0),
#  datetime.datetime(2006, 6, 14, 12, 0),
#  datetime.datetime(2006, 6, 14, 18, 0),
#  datetime.datetime(2006, 6, 15, 0, 0),
#  datetime.datetime(2006, 6, 15, 6, 0),
#  datetime.datetime(2006, 6, 15, 12, 0),
#  datetime.datetime(2006, 6, 15, 18, 0),
#  datetime.datetime(2006, 6, 16, 0, 0),
#  datetime.datetime(2006, 6, 16, 6, 0),
#  datetime.datetime(2006, 6, 16, 12, 0),
#  datetime.datetime(2006, 6, 16, 18, 0),
#  datetime.datetime(2006, 6, 17, 0, 0),
#  datetime.datetime(2006, 6, 17, 6, 0),
#  datetime.datetime(2006, 6, 17, 12, 0),
#  datetime.datetime(2006, 6, 17, 18, 0),
#  datetime.datetime(2006, 6, 18, 0, 0),
#  datetime.datetime(2006, 6, 18, 6, 0),
#  datetime.datetime(2006, 6, 18, 12, 0),
#  datetime.datetime(2006, 6, 18, 18, 0),
#  datetime.datetime(2006, 6, 19, 0, 0),
#  datetime.datetime(2006, 6, 19, 6, 0),
#  datetime.datetime(2006, 6, 19, 12, 0),
#  datetime.datetime(2006, 6, 19, 18, 0),
#  datetime.datetime(2006, 6, 20, 0, 0),
#  datetime.datetime(2006, 6, 20, 6, 0),
#  datetime.datetime(2006, 6, 20, 12, 0),
#  datetime.datetime(2006, 6, 20, 18, 0),
#  datetime.datetime(2006, 6, 21, 0, 0),
#  datetime.datetime(2006, 6, 21, 6, 0),
#  datetime.datetime(2006, 6, 21, 12, 0),
#  datetime.datetime(2006, 6, 21, 18, 0),
#  datetime.datetime(2006, 6, 22, 0, 0),
#  datetime.datetime(2006, 6, 22, 6, 0),
#  datetime.datetime(2006, 6, 22, 12, 0),
#  datetime.datetime(2006, 6, 22, 18, 0),
#  datetime.datetime(2006, 6, 23, 0, 0),
#  datetime.datetime(2006, 6, 23, 6, 0),
#  datetime.datetime(2006, 6, 23, 12, 0),
#  datetime.datetime(2006, 6, 23, 18, 0),
#  datetime.datetime(2006, 6, 24, 0, 0),
#  datetime.datetime(2006, 6, 24, 6, 0),
#  datetime.datetime(2006, 6, 24, 12, 0),
#  datetime.datetime(2006, 6, 24, 18, 0),
#  datetime.datetime(2006, 6, 25, 0, 0),
#  datetime.datetime(2006, 6, 25, 6, 0),
#  datetime.datetime(2006, 6, 25, 12, 0),
#  datetime.datetime(2006, 6, 25, 18, 0),
#  datetime.datetime(2006, 6, 26, 0, 0),
#  datetime.datetime(2006, 6, 26, 6, 0),
#  datetime.datetime(2006, 6, 26, 12, 0),
#  datetime.datetime(2006, 6, 26, 18, 0),
#  datetime.datetime(2006, 6, 27, 0, 0),
#  datetime.datetime(2006, 6, 27, 6, 0),
#  datetime.datetime(2006, 6, 27, 12, 0),
#  datetime.datetime(2006, 6, 27, 18, 0),
#  datetime.datetime(2006, 6, 28, 0, 0),
#  datetime.datetime(2006, 6, 28, 6, 0),
#  datetime.datetime(2006, 6, 28, 12, 0),
#  datetime.datetime(2006, 6, 28, 18, 0),
#  datetime.datetime(2006, 6, 29, 0, 0),
#  datetime.datetime(2006, 6, 29, 6, 0),
#  datetime.datetime(2006, 6, 29, 12, 0),
#  datetime.datetime(2006, 6, 29, 18, 0),
#  datetime.datetime(2006, 6, 30, 0, 0),
#  datetime.datetime(2006, 6, 30, 6, 0),
#  datetime.datetime(2006, 6, 30, 12, 0),
#  datetime.datetime(2006, 6, 30, 18, 0),
#  datetime.datetime(2006, 7, 1, 0, 0),
#  datetime.datetime(2006, 7, 1, 6, 0),
#  datetime.datetime(2006, 7, 1, 12, 0),
#  datetime.datetime(2006, 7, 1, 18, 0),
#  datetime.datetime(2006, 7, 2, 0, 0),
#  datetime.datetime(2006, 7, 2, 6, 0),
#  datetime.datetime(2006, 7, 2, 12, 0),
#  datetime.datetime(2006, 7, 2, 18, 0),
#  datetime.datetime(2006, 7, 3, 0, 0),
#  datetime.datetime(2006, 7, 3, 6, 0),
#  datetime.datetime(2006, 7, 3, 12, 0),
#  datetime.datetime(2006, 7, 3, 18, 0),
#  datetime.datetime(2006, 7, 4, 0, 0),
#  datetime.datetime(2006, 7, 4, 6, 0),
#  datetime.datetime(2006, 7, 4, 12, 0),
#  datetime.datetime(2006, 7, 4, 18, 0),
#  datetime.datetime(2006, 7, 5, 0, 0),
#  datetime.datetime(2006, 7, 5, 6, 0),
#  datetime.datetime(2006, 7, 5, 12, 0),
#  datetime.datetime(2006, 7, 5, 18, 0),
#  datetime.datetime(2006, 7, 6, 0, 0),
#  datetime.datetime(2006, 7, 6, 6, 0),
#  datetime.datetime(2006, 7, 6, 12, 0),
#  datetime.datetime(2006, 7, 6, 18, 0),
#  datetime.datetime(2006, 7, 7, 0, 0),
#  datetime.datetime(2006, 7, 7, 6, 0),
#  datetime.datetime(2006, 7, 7, 12, 0),
#  datetime.datetime(2006, 7, 7, 18, 0),
#  datetime.datetime(2006, 7, 8, 0, 0),
#  datetime.datetime(2006, 7, 8, 6, 0),
#  datetime.datetime(2006, 7, 8, 12, 0),
#  datetime.datetime(2006, 7, 8, 18, 0),
#  datetime.datetime(2006, 7, 9, 0, 0),
#  datetime.datetime(2006, 7, 9, 6, 0),
#  datetime.datetime(2006, 7, 9, 12, 0),
#  datetime.datetime(2006, 7, 9, 18, 0),
#  datetime.datetime(2006, 7, 10, 0, 0),
#  datetime.datetime(2006, 7, 10, 6, 0),
#  datetime.datetime(2006, 7, 10, 12, 0),
#  datetime.datetime(2006, 7, 10, 18, 0),
#  datetime.datetime(2006, 7, 11, 0, 0),
#  datetime.datetime(2006, 7, 11, 6, 0),
#  datetime.datetime(2006, 7, 11, 12, 0),
#  datetime.datetime(2006, 7, 11, 18, 0),
#  datetime.datetime(2006, 7, 12, 0, 0),
#  datetime.datetime(2006, 7, 12, 6, 0),
#  datetime.datetime(2006, 7, 12, 12, 0),
#  datetime.datetime(2006, 7, 12, 18, 0),
#  datetime.datetime(2006, 7, 13, 0, 0),
#  datetime.datetime(2006, 7, 13, 6, 0),
#  datetime.datetime(2006, 7, 13, 12, 0),
#  datetime.datetime(2006, 7, 13, 18, 0),
#  datetime.datetime(2006, 7, 14, 0, 0),
#  datetime.datetime(2006, 7, 14, 6, 0),
#  datetime.datetime(2006, 7, 14, 12, 0),
#  datetime.datetime(2006, 7, 14, 18, 0),
#  datetime.datetime(2006, 7, 15, 0, 0),
#  datetime.datetime(2006, 7, 15, 6, 0),
#  datetime.datetime(2006, 7, 15, 12, 0),
#  datetime.datetime(2006, 7, 15, 18, 0),
#  datetime.datetime(2006, 7, 16, 0, 0),
#  datetime.datetime(2006, 7, 16, 6, 0),
#  datetime.datetime(2006, 7, 16, 12, 0),
#  datetime.datetime(2006, 7, 16, 18, 0),
#  datetime.datetime(2006, 7, 17, 0, 0),
#  datetime.datetime(2006, 7, 17, 6, 0),
#  datetime.datetime(2006, 7, 17, 12, 0),
#  datetime.datetime(2006, 7, 17, 18, 0),
#  datetime.datetime(2006, 7, 18, 0, 0),
#  datetime.datetime(2006, 7, 18, 6, 0),
#  datetime.datetime(2006, 7, 18, 12, 0),
#  datetime.datetime(2006, 7, 18, 18, 0),
#  datetime.datetime(2006, 7, 19, 0, 0),
#  datetime.datetime(2006, 7, 19, 6, 0),
#  datetime.datetime(2006, 7, 19, 12, 0),
#  datetime.datetime(2006, 7, 19, 18, 0),
#  datetime.datetime(2006, 7, 20, 0, 0),
#  datetime.datetime(2006, 7, 20, 6, 0),
#  datetime.datetime(2006, 7, 20, 12, 0),
#  datetime.datetime(2006, 7, 20, 18, 0),
#  datetime.datetime(2006, 7, 21, 0, 0),
#  datetime.datetime(2006, 7, 21, 6, 0),
#  datetime.datetime(2006, 7, 21, 12, 0),
#  datetime.datetime(2006, 7, 21, 18, 0),
#  datetime.datetime(2006, 7, 22, 0, 0),
#  datetime.datetime(2006, 7, 22, 6, 0),
#  datetime.datetime(2006, 7, 22, 12, 0),
#  datetime.datetime(2006, 7, 22, 18, 0),
#  datetime.datetime(2006, 7, 23, 0, 0),
#  datetime.datetime(2006, 7, 23, 6, 0),
#  datetime.datetime(2006, 7, 23, 12, 0),
#  datetime.datetime(2006, 7, 23, 18, 0),
#  datetime.datetime(2006, 7, 24, 0, 0),
#  datetime.datetime(2006, 7, 24, 6, 0),
#  datetime.datetime(2006, 7, 24, 12, 0),
#  datetime.datetime(2006, 7, 24, 18, 0),
#  datetime.datetime(2006, 7, 25, 0, 0),
#  datetime.datetime(2006, 7, 25, 6, 0),
#  datetime.datetime(2006, 7, 25, 12, 0),
#  datetime.datetime(2006, 7, 25, 18, 0),
#  datetime.datetime(2006, 7, 26, 0, 0),
#  datetime.datetime(2006, 7, 26, 6, 0),
#  datetime.datetime(2006, 7, 26, 12, 0),
#  datetime.datetime(2006, 7, 26, 18, 0),
#  datetime.datetime(2006, 7, 27, 0, 0),
#  datetime.datetime(2006, 7, 27, 6, 0),
#  datetime.datetime(2006, 7, 27, 12, 0),
#  datetime.datetime(2006, 7, 27, 18, 0),
#  datetime.datetime(2006, 7, 28, 0, 0),
#  datetime.datetime(2006, 7, 28, 6, 0),
#  datetime.datetime(2006, 7, 28, 12, 0),
#  datetime.datetime(2006, 7, 28, 18, 0),
#  datetime.datetime(2006, 7, 29, 0, 0),
#  datetime.datetime(2006, 7, 29, 6, 0),
#  datetime.datetime(2006, 7, 29, 12, 0),
#  datetime.datetime(2006, 7, 29, 18, 0),
#  datetime.datetime(2006, 7, 30, 0, 0),
#  datetime.datetime(2006, 7, 30, 6, 0),
#  datetime.datetime(2006, 7, 30, 12, 0),
#  datetime.datetime(2006, 7, 30, 18, 0),
#  datetime.datetime(2006, 7, 31, 0, 0),
#  datetime.datetime(2006, 7, 31, 6, 0),
#  datetime.datetime(2006, 7, 31, 12, 0),
#  datetime.datetime(2006, 7, 31, 18, 0),
#  datetime.datetime(2006, 8, 1, 0, 0),
#  datetime.datetime(2006, 8, 1, 6, 0),
#  datetime.datetime(2006, 8, 1, 12, 0),
#  datetime.datetime(2006, 8, 1, 18, 0),
#  datetime.datetime(2006, 8, 2, 0, 0),
#  datetime.datetime(2006, 8, 2, 6, 0),
#  datetime.datetime(2006, 8, 2, 12, 0),
#  datetime.datetime(2006, 8, 2, 18, 0),
#  datetime.datetime(2006, 8, 3, 0, 0),
#  datetime.datetime(2006, 8, 3, 6, 0),
#  datetime.datetime(2006, 8, 3, 12, 0),
#  datetime.datetime(2006, 8, 3, 18, 0),
#  datetime.datetime(2006, 8, 4, 0, 0),
#  datetime.datetime(2006, 8, 4, 6, 0),
#  datetime.datetime(2006, 8, 4, 12, 0),
#  datetime.datetime(2006, 8, 4, 18, 0),
#  datetime.datetime(2006, 8, 5, 0, 0),
#  datetime.datetime(2006, 8, 5, 6, 0),
#  datetime.datetime(2006, 8, 5, 12, 0),
#  datetime.datetime(2006, 8, 5, 18, 0),
#  datetime.datetime(2006, 8, 6, 0, 0),
#  datetime.datetime(2006, 8, 6, 6, 0),
#  datetime.datetime(2006, 8, 6, 12, 0),
#  datetime.datetime(2006, 8, 6, 18, 0),
#  datetime.datetime(2006, 8, 7, 0, 0),
#  datetime.datetime(2006, 8, 7, 6, 0),
#  datetime.datetime(2006, 8, 7, 12, 0),
#  datetime.datetime(2006, 8, 7, 18, 0),
#  datetime.datetime(2006, 8, 8, 0, 0),
#  datetime.datetime(2006, 8, 8, 6, 0),
#  datetime.datetime(2006, 8, 8, 12, 0),
#  datetime.datetime(2006, 8, 8, 18, 0),
#  datetime.datetime(2006, 8, 9, 0, 0),
#  datetime.datetime(2006, 8, 9, 6, 0),
#  datetime.datetime(2006, 8, 9, 12, 0),
#  datetime.datetime(2006, 8, 9, 18, 0),
#  datetime.datetime(2006, 8, 10, 0, 0),
#  datetime.datetime(2006, 8, 10, 6, 0),
#  datetime.datetime(2006, 8, 10, 12, 0),
#  datetime.datetime(2006, 8, 10, 18, 0),
#  datetime.datetime(2006, 8, 11, 0, 0),
#  datetime.datetime(2006, 8, 11, 6, 0),
#  datetime.datetime(2006, 8, 11, 12, 0),
#  datetime.datetime(2006, 8, 11, 18, 0),
#  datetime.datetime(2006, 8, 12, 0, 0),
#  datetime.datetime(2006, 8, 12, 6, 0),
#  datetime.datetime(2006, 8, 12, 12, 0),
#  datetime.datetime(2006, 8, 12, 18, 0),
#  datetime.datetime(2006, 8, 13, 0, 0),
#  datetime.datetime(2006, 8, 13, 6, 0),
#  datetime.datetime(2006, 8, 13, 12, 0),
#  datetime.datetime(2006, 8, 13, 18, 0),
#  datetime.datetime(2006, 8, 14, 0, 0),
#  datetime.datetime(2006, 8, 14, 6, 0),
#  datetime.datetime(2006, 8, 14, 12, 0),
#  datetime.datetime(2006, 8, 14, 18, 0),
#  datetime.datetime(2006, 8, 15, 0, 0),
#  datetime.datetime(2006, 8, 15, 6, 0),
#  datetime.datetime(2006, 8, 15, 12, 0),
#  datetime.datetime(2006, 8, 15, 18, 0),
#  datetime.datetime(2006, 8, 16, 0, 0),
#  datetime.datetime(2006, 8, 16, 6, 0),
#  datetime.datetime(2006, 8, 16, 12, 0),
#  datetime.datetime(2006, 8, 16, 18, 0),
#  datetime.datetime(2006, 8, 17, 0, 0),
#  datetime.datetime(2006, 8, 17, 6, 0),
#  datetime.datetime(2006, 8, 17, 12, 0),
#  datetime.datetime(2006, 8, 17, 18, 0),
#  datetime.datetime(2006, 8, 18, 0, 0),
#  datetime.datetime(2006, 8, 18, 6, 0),
#  datetime.datetime(2006, 8, 18, 12, 0),
#  datetime.datetime(2006, 8, 18, 18, 0),
#  datetime.datetime(2006, 8, 19, 0, 0),
#  datetime.datetime(2006, 8, 19, 6, 0),
#  datetime.datetime(2006, 8, 19, 12, 0),
#  datetime.datetime(2006, 8, 19, 18, 0),
#  datetime.datetime(2006, 8, 20, 0, 0),
#  datetime.datetime(2006, 8, 20, 6, 0),
#  datetime.datetime(2006, 8, 20, 12, 0),
#  datetime.datetime(2006, 8, 20, 18, 0),
#  datetime.datetime(2006, 8, 21, 0, 0),
#  datetime.datetime(2006, 8, 21, 6, 0),
#  datetime.datetime(2006, 8, 21, 12, 0),
#  datetime.datetime(2006, 8, 21, 18, 0),
#  datetime.datetime(2006, 8, 22, 0, 0),
#  datetime.datetime(2006, 8, 22, 6, 0),
#  datetime.datetime(2006, 8, 22, 12, 0),
#  datetime.datetime(2006, 8, 22, 18, 0),
#  datetime.datetime(2006, 8, 23, 0, 0),
#  datetime.datetime(2006, 8, 23, 6, 0),
#  datetime.datetime(2006, 8, 23, 12, 0),
#  datetime.datetime(2006, 8, 23, 18, 0),
#  datetime.datetime(2006, 8, 24, 0, 0),
#  datetime.datetime(2006, 8, 24, 6, 0),
#  datetime.datetime(2006, 8, 24, 12, 0),
#  datetime.datetime(2006, 8, 24, 18, 0),
#  datetime.datetime(2006, 8, 25, 0, 0),
#  datetime.datetime(2006, 8, 25, 6, 0),
#  datetime.datetime(2006, 8, 25, 12, 0),
#  datetime.datetime(2006, 8, 25, 18, 0),
#  datetime.datetime(2006, 8, 26, 0, 0),
#  datetime.datetime(2006, 8, 26, 6, 0),
#  datetime.datetime(2006, 8, 26, 12, 0),
#  datetime.datetime(2006, 8, 26, 18, 0),
#  datetime.datetime(2006, 8, 27, 0, 0),
#  datetime.datetime(2006, 8, 27, 6, 0),
#  datetime.datetime(2006, 8, 27, 12, 0),
#  datetime.datetime(2006, 8, 27, 18, 0),
#  datetime.datetime(2006, 8, 28, 0, 0),
#  datetime.datetime(2006, 8, 28, 6, 0),
#  datetime.datetime(2006, 8, 28, 12, 0),
#  datetime.datetime(2006, 8, 28, 18, 0),
#  datetime.datetime(2006, 8, 29, 0, 0),
#  datetime.datetime(2006, 8, 29, 6, 0),
#  datetime.datetime(2006, 8, 29, 12, 0),
#  datetime.datetime(2006, 8, 29, 18, 0),
#  datetime.datetime(2006, 8, 30, 0, 0),
#  datetime.datetime(2006, 8, 30, 6, 0),
#  datetime.datetime(2006, 8, 30, 12, 0),
#  datetime.datetime(2006, 8, 30, 18, 0),
#  datetime.datetime(2006, 8, 31, 0, 0),
#  datetime.datetime(2006, 8, 31, 6, 0),
#  datetime.datetime(2006, 8, 31, 12, 0),
#  datetime.datetime(2006, 8, 31, 18, 0),
#  datetime.datetime(2006, 9, 1, 0, 0),
#  datetime.datetime(2006, 9, 1, 6, 0),
#  datetime.datetime(2006, 9, 1, 12, 0),
#  datetime.datetime(2006, 9, 1, 18, 0),
#  datetime.datetime(2006, 9, 2, 0, 0),
#  datetime.datetime(2006, 9, 2, 6, 0),
#  datetime.datetime(2006, 9, 2, 12, 0),
#  datetime.datetime(2006, 9, 2, 18, 0),
#  datetime.datetime(2006, 9, 3, 0, 0),
#  datetime.datetime(2006, 9, 3, 6, 0),
#  datetime.datetime(2006, 9, 3, 12, 0),
#  datetime.datetime(2006, 9, 3, 18, 0),
#  datetime.datetime(2006, 9, 4, 0, 0),
#  datetime.datetime(2006, 9, 4, 6, 0),
#  datetime.datetime(2006, 9, 4, 12, 0),
#  datetime.datetime(2006, 9, 4, 18, 0),
#  datetime.datetime(2006, 9, 5, 0, 0),
#  datetime.datetime(2006, 9, 5, 6, 0),
#  datetime.datetime(2006, 9, 5, 12, 0),
#  datetime.datetime(2006, 9, 5, 18, 0),
#  datetime.datetime(2006, 9, 6, 0, 0),
#  datetime.datetime(2006, 9, 6, 6, 0),
#  datetime.datetime(2006, 9, 6, 12, 0),
#  datetime.datetime(2006, 9, 6, 18, 0),
#  datetime.datetime(2006, 9, 7, 0, 0),
#  datetime.datetime(2006, 9, 7, 6, 0),
#  datetime.datetime(2006, 9, 7, 12, 0),
#  datetime.datetime(2006, 9, 7, 18, 0),
#  datetime.datetime(2006, 9, 8, 0, 0),
#  datetime.datetime(2006, 9, 8, 6, 0),
#  datetime.datetime(2006, 9, 8, 12, 0),
#  datetime.datetime(2006, 9, 8, 18, 0),
#  datetime.datetime(2006, 9, 9, 0, 0),
#  datetime.datetime(2006, 9, 9, 6, 0),
#  datetime.datetime(2006, 9, 9, 12, 0),
#  datetime.datetime(2006, 9, 9, 18, 0),
#  datetime.datetime(2006, 9, 10, 0, 0),
#  datetime.datetime(2006, 9, 10, 6, 0),
#  datetime.datetime(2006, 9, 10, 12, 0),
#  datetime.datetime(2006, 9, 10, 18, 0),
#  datetime.datetime(2006, 9, 11, 0, 0),
#  datetime.datetime(2006, 9, 11, 6, 0),
#  datetime.datetime(2006, 9, 11, 12, 0),
#  datetime.datetime(2006, 9, 11, 18, 0),
#  datetime.datetime(2006, 9, 12, 0, 0),
#  datetime.datetime(2006, 9, 12, 6, 0),
#  datetime.datetime(2006, 9, 12, 12, 0),
#  datetime.datetime(2006, 9, 12, 18, 0),
#  datetime.datetime(2006, 9, 13, 0, 0),
#  datetime.datetime(2006, 9, 13, 6, 0),
#  datetime.datetime(2006, 9, 13, 12, 0),
#  datetime.datetime(2006, 9, 13, 18, 0),
#  datetime.datetime(2006, 9, 14, 0, 0),
#  datetime.datetime(2006, 9, 14, 6, 0),
#  datetime.datetime(2006, 9, 14, 12, 0),
#  datetime.datetime(2006, 9, 14, 18, 0),
#  datetime.datetime(2006, 9, 15, 0, 0),
#  datetime.datetime(2006, 9, 15, 6, 0),
#  datetime.datetime(2006, 9, 15, 12, 0),
#  datetime.datetime(2006, 9, 15, 18, 0),
#  datetime.datetime(2006, 9, 16, 0, 0),
#  datetime.datetime(2006, 9, 16, 6, 0),
#  datetime.datetime(2006, 9, 16, 12, 0),
#  datetime.datetime(2006, 9, 16, 18, 0),
#  datetime.datetime(2006, 9, 17, 0, 0),
#  datetime.datetime(2006, 9, 17, 6, 0),
#  datetime.datetime(2006, 9, 17, 12, 0),
#  datetime.datetime(2006, 9, 17, 18, 0),
#  datetime.datetime(2006, 9, 18, 0, 0),
#  datetime.datetime(2006, 9, 18, 6, 0),
#  datetime.datetime(2006, 9, 18, 12, 0),
#  datetime.datetime(2006, 9, 18, 18, 0),
#  datetime.datetime(2006, 9, 19, 0, 0),
#  datetime.datetime(2006, 9, 19, 6, 0),
#  datetime.datetime(2006, 9, 19, 12, 0),
#  datetime.datetime(2006, 9, 19, 18, 0),
#  datetime.datetime(2006, 9, 20, 0, 0),
#  datetime.datetime(2006, 9, 20, 6, 0),
#  datetime.datetime(2006, 9, 20, 12, 0),
#  datetime.datetime(2006, 9, 20, 18, 0),
#  datetime.datetime(2006, 9, 21, 0, 0),
#  datetime.datetime(2006, 9, 21, 6, 0),
#  datetime.datetime(2006, 9, 21, 12, 0),
#  datetime.datetime(2006, 9, 21, 18, 0),
#  datetime.datetime(2006, 9, 22, 0, 0),
#  datetime.datetime(2006, 9, 22, 6, 0),
#  datetime.datetime(2006, 9, 22, 12, 0),
#  datetime.datetime(2006, 9, 22, 18, 0),
#  datetime.datetime(2006, 9, 23, 0, 0),
#  datetime.datetime(2006, 9, 23, 6, 0),
#  datetime.datetime(2006, 9, 23, 12, 0),
#  datetime.datetime(2006, 9, 23, 18, 0),
#  datetime.datetime(2006, 9, 24, 0, 0),
#  datetime.datetime(2006, 9, 24, 6, 0),
#  datetime.datetime(2006, 9, 24, 12, 0),
#  datetime.datetime(2006, 9, 24, 18, 0),
#  datetime.datetime(2006, 9, 25, 0, 0),
#  datetime.datetime(2006, 9, 25, 6, 0),
#  datetime.datetime(2006, 9, 25, 12, 0),
#  datetime.datetime(2006, 9, 25, 18, 0),
#  datetime.datetime(2006, 9, 26, 0, 0),
#  datetime.datetime(2006, 9, 26, 6, 0),
#  datetime.datetime(2006, 9, 26, 12, 0),
#  datetime.datetime(2006, 9, 26, 18, 0),
#  datetime.datetime(2006, 9, 27, 0, 0),
#  datetime.datetime(2006, 9, 27, 6, 0),
#  datetime.datetime(2006, 9, 27, 12, 0),
#  datetime.datetime(2006, 9, 27, 18, 0),
#  datetime.datetime(2006, 9, 28, 0, 0),
#  datetime.datetime(2006, 9, 28, 6, 0),
#  datetime.datetime(2006, 9, 28, 12, 0),
#  datetime.datetime(2006, 9, 28, 18, 0),
#  datetime.datetime(2006, 9, 29, 0, 0),
#  datetime.datetime(2006, 9, 29, 6, 0),
#  datetime.datetime(2006, 9, 29, 12, 0),
#  datetime.datetime(2006, 9, 29, 18, 0),
#  datetime.datetime(2006, 9, 30, 0, 0),
#  datetime.datetime(2006, 9, 30, 6, 0),
#  datetime.datetime(2006, 9, 30, 12, 0),
#  datetime.datetime(2006, 9, 30, 18, 0),
#  datetime.datetime(2006, 10, 1, 0, 0),
#  datetime.datetime(2006, 10, 1, 6, 0),
#  datetime.datetime(2006, 10, 1, 12, 0),
#  datetime.datetime(2006, 10, 1, 18, 0),
#  datetime.datetime(2006, 10, 2, 0, 0),
#  datetime.datetime(2006, 10, 2, 6, 0),
#  datetime.datetime(2006, 10, 2, 12, 0),
#  datetime.datetime(2006, 10, 2, 18, 0),
#  datetime.datetime(2006, 10, 3, 0, 0),
#  datetime.datetime(2006, 10, 3, 6, 0),
#  datetime.datetime(2006, 10, 3, 12, 0),
#  datetime.datetime(2006, 10, 3, 18, 0),
#  datetime.datetime(2006, 10, 4, 0, 0),
#  datetime.datetime(2006, 10, 4, 6, 0),
#  datetime.datetime(2006, 10, 4, 12, 0),
#  datetime.datetime(2006, 10, 4, 18, 0),
#  datetime.datetime(2006, 10, 5, 0, 0),
#  datetime.datetime(2006, 10, 5, 6, 0),
#  datetime.datetime(2006, 10, 5, 12, 0),
#  datetime.datetime(2006, 10, 5, 18, 0),
#  datetime.datetime(2006, 10, 6, 0, 0),
#  datetime.datetime(2006, 10, 6, 6, 0),
#  datetime.datetime(2006, 10, 6, 12, 0),
#  datetime.datetime(2006, 10, 6, 18, 0),
#  datetime.datetime(2006, 10, 7, 0, 0),
#  datetime.datetime(2006, 10, 7, 6, 0),
#  datetime.datetime(2006, 10, 7, 12, 0),
#  datetime.datetime(2006, 10, 7, 18, 0),
#  datetime.datetime(2006, 10, 8, 0, 0),
#  datetime.datetime(2006, 10, 8, 6, 0),
#  datetime.datetime(2006, 10, 8, 12, 0),
#  datetime.datetime(2006, 10, 8, 18, 0),
#  ...]

# %%
vname='indice'
time_index=0
vbl0=nc.variables[vname]
indices=
